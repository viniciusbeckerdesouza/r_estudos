# %% [markdown]
# ### tidyverse

# %%
library(tidyverse)
# Out:
# Warning message:
# "package 'tidyverse' was built under R version 3.6.3"-- Attaching packages --------------------------------------- tidyverse 1.3.0 --
# v ggplot2 3.3.2     v purrr   0.3.4
# v tibble  3.0.4     v dplyr   1.0.2
# v tidyr   1.1.2     v stringr 1.4.0
# v readr   1.3.1     v forcats 0.4.0
# Warning message:
# "package 'ggplot2' was built under R version 3.6.3"Warning message:
# "package 'tibble' was built under R version 3.6.3"Warning message:
# "package 'tidyr' was built under R version 3.6.3"Warning message:
# "package 'purrr' was built under R version 3.6.3"Warning message:
# "package 'dplyr' was built under R version 3.6.3"-- Conflicts ------------------------------------------ tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# x dplyr::lag()    masks stats::lag()

# %%
version
# Out:
#                _
# platform       x86_64-w64-mingw32
# arch           x86_64
# os             mingw32
# system         x86_64, mingw32
# status
# major          3
# minor          6.1
# year           2019
# month          07
# day            05
# svn rev        76782
# language       R
# version.string R version 3.6.1 (2019-07-05)
# nickname       Action of the Toes

# %%
#conda update r-caret

# %% [markdown]
# ### mpg data frame

# %%
mpg
# Out:
#     manufacturer model              displ year cyl trans      drv cty hwy fl
# 1   audi         a4                 1.8   1999 4   auto(l5)   f   18  29  p
# 2   audi         a4                 1.8   1999 4   manual(m5) f   21  29  p
# 3   audi         a4                 2.0   2008 4   manual(m6) f   20  31  p
# 4   audi         a4                 2.0   2008 4   auto(av)   f   21  30  p
# 5   audi         a4                 2.8   1999 6   auto(l5)   f   16  26  p
# 6   audi         a4                 2.8   1999 6   manual(m5) f   18  26  p
# 7   audi         a4                 3.1   2008 6   auto(av)   f   18  27  p
# 8   audi         a4 quattro         1.8   1999 4   manual(m5) 4   18  26  p
# 9   audi         a4 quattro         1.8   1999 4   auto(l5)   4   16  25  p
# 10  audi         a4 quattro         2.0   2008 4   manual(m6) 4   20  28  p
# 11  audi         a4 quattro         2.0   2008 4   auto(s6)   4   19  27  p
# ...

# %%
#?mpg

# %% [markdown]
# ### ggplot

# %%
ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy))
# Out:
# plot without title

# %%
ggplot(data = mpg) + 
  geom_point(mapping = aes(x = trans, y = hwy))
# Out:
# plot without title

# %%
ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy, color = class))
# Out:
# plot without title

# %%
ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy, color = trans))
# Out:
# plot without title

# %%
ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy, size = class))
#> Warning: Using size for a discrete variable is not advised.
# Out:
# Warning message:
# "Using size for a discrete variable is not advised."
# plot without title

# %%
ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy, size = trans))
# Out:
# Warning message:
# "Using size for a discrete variable is not advised."
# plot without title

# %%
# Left
ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy, alpha = class))

# Right
ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy, shape = class))
# Out:
# Warning message:
# "Using alpha for a discrete variable is not advised."Warning message:
# "The shape palette can deal with a maximum of 6 discrete values because
# more than 6 becomes difficult to discriminate; you have 7. Consider
# specifying shapes manually if you must have them."Warning message:
# "Removed 62 rows containing missing values (geom_point)."
# plot without title
# plot without title

# %%
# Left
ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy, alpha = trans))

# Right
ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy, shape = trans))
# Out:
# Warning message:
# "Using alpha for a discrete variable is not advised."Warning message:
# "The shape palette can deal with a maximum of 6 discrete values because
# more than 6 becomes difficult to discriminate; you have 10. Consider
# specifying shapes manually if you must have them."Warning message:
# "Removed 96 rows containing missing values (geom_point)."
# plot without title
# plot without title

# %%
ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy), color = "blue")
# Out:
# plot without title

# %%
ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy), color = "green")
# Out:
# plot without title

# %%
ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy), shape = 9)
# Out:
# plot without title

# %%
ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy), shape = 15)
# Out:
# plot without title

# %%
ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy), shape = 23)
# Out:
# plot without title

# %%
ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy), shape = 11)
# Out:
# plot without title

# %% [markdown]
# ### Exercicios

# %% [markdown]
# ##### What’s gone wrong with this code? Why are the points not blue?

# %%
ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy, color = "blue"))
# Out:
# plot without title

# %% [markdown]
# R: color está sendo usado para classificar os resultados como se blue fosse uma variável.
# O certo é:

# %%
ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy), color = "blue")
# Out:
# plot without title

# %% [markdown]
# ##### Which variables in mpg are categorical? Which variables are continuous? (Hint: type ?mpg to read the documentation for the dataset). How can you see this information when you run mpg?

# %%
#?mpg

# %% [markdown]
# **categorical**: manufacturer, model, trans, drv, fl, class
# **continous**: displ, year, cyl, cty, hwy

# %% [markdown]
# ##### Map a continuous variable to color, size, and shape. How do these aesthetics behave differently for categorical vs. continuous variables?

# %%
ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy, color = year))
# Out:
# plot without title

# %%
ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy, size = year))
# Out:
# plot without title

# %%
ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy, shape = year))
# Out:
# ERROR while rich displaying an object: Error: A continuous variable can not be mapped to shape
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# ...

# %% [markdown]
# Size funciona para continuos mas não para catogrials. Shape é o contrário

# %% [markdown]
# ##### What happens if you map the same variable to multiple aesthetics?

# %%
ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy, color = fl, size = fl, shape = fl))
# Out:
# Warning message:
# "Using size for a discrete variable is not advised."
# plot without title

# %% [markdown]
# Fica uma bagunça kkkk

# %% [markdown]
# ##### What does the stroke aesthetic do? What shapes does it work with? (Hint: use ?geom_point)

# %%
ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy, stroke = cyl))
# Out:
# plot without title

# %%
ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy, stroke = cty))
# Out:
# plot without title

# %% [markdown]
# Gera um gráfico de bolhas

# %% [markdown]
# ##### What happens if you map an aesthetic to something other than a variable name, like aes(colour = displ < 5)? Note, you’ll also need to specify x and y.

# %%
ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy, colour = displ < 5))
# Out:
# plot without title

# %%
ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy, colour = cty < 12))
# Out:
# plot without title

# %% [markdown]
# As cores mostram os pontos que correspondem ao valor booleano

# %% [markdown]
# ### Facets

# %%
ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy)) + 
  facet_wrap(~ class, nrow = 2)
# Out:
# plot without title

# %%
ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy)) + 
  facet_wrap(~ trans, nrow = 4)
# Out:
# plot without title

# %%
ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy)) + 
  facet_grid(drv ~ cyl)
# Out:
# plot without title

# %%
ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy)) + 
  facet_grid(. ~ cyl)
# Out:
# plot without title

# %% [markdown]
# ### Exercícios

# %% [markdown]
# ##### What happens if you facet on a continuous variable?

# %%
ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy)) + 
  facet_wrap(~ cyl, nrow = 4)
# Out:
# plot without title

# %% [markdown]
# ##### What do the empty cells in plot with facet_grid(drv ~ cyl) mean? How do they relate to this plot?

# %%
ggplot(data = mpg) + 
  geom_point(mapping = aes(x = drv, y = cyl))
# Out:
# plot without title

# %% [markdown]
# Os espaços em brancos correspondem aos valores que não se cruzam na comparação entre cyl e drv

# %% [markdown]
# ##### What plots does the following code make? What does . do?

# %%
ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy)) +
  facet_grid(drv ~ .)

ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy)) +
  facet_grid(. ~ cyl)
# Out:
# plot without title
# plot without title

# %% [markdown]
# O ponto faz com que os dados cruzem consigo mesmo

# %% [markdown]
# ##### Take the first faceted plot in this section:

# %%
ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy)) + 
  facet_wrap(~ class, nrow = 2)
# Out:
# plot without title

# %%
ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy, color = class))
# Out:
# plot without title

# %% [markdown]
# Os facets perimtem recortar os dados por categoria. O uso de cor permite uma visão global dos dados.

# %% [markdown]
# ##### Read ?facet_wrap. What does nrow do? What does ncol do? What other options control the layout of the individual panels? Why doesn’t facet_grid() have nrow and ncol arguments?

# %%
?facet_wrap

# %% [markdown]
# ncol: número de colunas
# nrow: número de rows
# scales, shrink

# %%
ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy)) + 
  facet_wrap(~ class, nrow = 2, scale='free')
# Out:
# plot without title

# %% [markdown]
# ##### When using facet_grid() you should usually put the variable with more unique levels in the columns. Why?

# %% [markdown]
# Para ter um número menor de grids, facilitando a visualização.

# %% [markdown]
# ### Objetos Geométricos

# %%
# left
ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy))

# right
ggplot(data = mpg) + 
  geom_smooth(mapping = aes(x = displ, y = hwy))
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title
# plot without title

# %%
ggplot(data = mpg) + 
  geom_smooth(mapping = aes(x = displ, y = hwy, linetype = drv))
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
ggplot(data = mpg) +
  geom_smooth(mapping = aes(x = displ, y = hwy))
              
ggplot(data = mpg) +
  geom_smooth(mapping = aes(x = displ, y = hwy, group = drv))
    
ggplot(data = mpg) +
  geom_smooth(
    mapping = aes(x = displ, y = hwy, color = drv),
    show.legend = FALSE
  )
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title
# plot without title

# %%
ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy)) +
  geom_smooth(mapping = aes(x = displ, y = hwy))
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
ggplot(data = mpg, mapping = aes(x = displ, y = hwy)) + 
  geom_point(mapping = aes(color = class)) + 
  geom_smooth()
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
ggplot(data = mpg, mapping = aes(x = displ, y = hwy)) + 
  geom_point(mapping = aes(color = class)) + 
  geom_smooth(data = filter(mpg, class == "subcompact"), se = FALSE)
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %% [markdown]
# ##### What geom would you use to draw a line chart? A boxplot? A histogram? An area chart?

# %%
ggplot(data = mpg, mapping = aes(x = displ)) +
  geom_histogram()
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
ggplot(data = mpg, mapping = aes(x = displ)) +
  geom_boxplot()
# Out:
# plot without title

# %%
ggplot(data = mpg, mapping = aes(x = displ,y = hwy)) +
  geom_line()
# Out:
# plot without title

# %%
ggplot(data = mpg, mapping = aes(x = displ,y = hwy)) +
  geom_area()
# Out:
# plot without title

# %% [markdown]
# ##### Run this code in your head and predict what the output will look like. Then, run the code in R and check your predictions.

# %%
ggplot(data = mpg, mapping = aes(x = displ, y = hwy, color = drv)) + 
  geom_point() + 
  geom_smooth(se = FALSE)
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %% [markdown]
# ##### What does show.legend = FALSE do? What happens if you remove it?
# Why do you think I used it earlier in the chapter?

# %%
ggplot(data = mpg) +
  geom_smooth(
    mapping = aes(x = displ, y = hwy, color = drv),
    show.legend = TRUE #Esconde a legenda
  )
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %% [markdown]
# ##### What does the se argument to geom_smooth() do?

# %%
ggplot(data = mpg, mapping = aes(x = displ, y = hwy, color = drv)) + 
  geom_point() + 
  geom_smooth(se = FALSE) #Liga e desliga a sombra

ggplot(data = mpg, mapping = aes(x = displ, y = hwy, color = drv)) + 
  geom_point() + 
  geom_smooth(se = TRUE)
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title
# plot without title

# %% [markdown]
# ##### Will these two graphs look different? Why/why not?

# %%
ggplot(data = mpg, mapping = aes(x = displ, y = hwy)) + 
  geom_point() + 
  geom_smooth()

ggplot() + 
  geom_point(data = mpg, mapping = aes(x = displ, y = hwy)) + 
  geom_smooth(data = mpg, mapping = aes(x = displ, y = hwy))

#Mesmo resultado
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title
# plot without title

# %% [markdown]
# ##### Recreate the R code necessary to generate the following graphs.

# %% [markdown]
# ![image.png](attachment:image.png)![image-2.png](attachment:image-2.png)![image-3.png](attachment:image-3.png)![image-4.png](attachment:image-4.png)![image-5.png](attachment:image-5.png)![image-6.png](attachment:image-6.png)

# %%
# Out:
# Error in geom_size(): não foi possível encontrar a função "geom_size"
# Traceback:

# %% [markdown]
# ### Transformação Estatística

# %%
ggplot(data = diamonds) + 
  geom_bar(mapping = aes(x = cut))
# Out:
# plot without title

# %%
ggplot(data = diamonds) + 
  geom_boxplot(mapping = aes(x = price))
# Out:
# plot without title

# %%
ggplot(data = diamonds) + 
  geom_bar(mapping = aes(x = color))
# Out:
# plot without title

# %%
demo <- tribble(
  ~cut,         ~freq,
  "Fair",       1610,
  "Good",       4906,
  "Very Good",  12082,
  "Premium",    13791,
  "Ideal",      21551
)

ggplot(data = demo) +
  geom_bar(mapping = aes(x = cut, y = freq), stat = "identity")
# Out:
# plot without title

# %%
ggplot(data = diamonds) + 
  geom_bar(mapping = aes(x = cut, y = stat(prop), group = 1))
# Out:
# plot without title

# %%
ggplot(data = diamonds) + 
  stat_summary(
    mapping = aes(x = cut, y = depth),
    fun.min = min,
    fun.max = max,
    fun = median
  )
# Out:
# plot without title

# %% [markdown]
# ##### What is the default geom associated with stat_summary()? How could you rewrite the previous plot to use that geom function instead of the stat function?

# %%
?stat_summary()

# %% [markdown]
# ##### What does geom_col() do? How is it different to geom_bar()?

# %% [markdown]
# ##### Most geoms and stats come in pairs that are almost always used in concert. Read through the documentation and make a list of all the pairs. What do they have in common?

# %% [markdown]
# ##### What variables does stat_smooth() compute? What parameters control its behaviour?

# %% [markdown]
# ##### In our proportion bar chart, we need to set group = 1. Why? In other words what is the problem with these two graphs?

# %%
ggplot(data = diamonds) + 
  geom_bar(mapping = aes(x = cut, y = after_stat(prop)))
ggplot(data = diamonds) + 
  geom_bar(mapping = aes(x = cut, fill = color, y = after_stat(prop)))
# Out:
# plot without title
# plot without title
